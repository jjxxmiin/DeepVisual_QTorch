# %%
import os
import sys
import copy
import numpy as np
import pickle
import torch
import torchvision.models as models

from PIL import Image

from torch.autograd import Variable
from torch.optim import SGD

# %%
if torch.cuda.is_available():
    device = 'cuda'
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
else:
    device = 'cpu'
    torch.set_default_tensor_type('torch.FloatTensor')

# %%
with open("imagenet_labels.pkl", "rb") as f:
    class_name = pickle.load(f)

# %%
model = models.resnet18(pretrained=True)

# %%
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
def preprocess_image(img):
    mean = [0.4914, 0.4822, 0.4465]
    std = [0.2023, 0.1994, 0.2010]
    
    im_as_arr = np.float32(img)
    im_as_arr = im_as_arr.transpose(2, 0, 1)
    
    # 채널 정규화
    for channel, _ in enumerate(im_as_arr):
        im_as_arr[channel] /= 255
        im_as_arr[channel] -= mean[channel]
        im_as_arr[channel] /= std[channel]
        
    # tensor
    im_as_ten = torch.from_numpy(im_as_arr).float()
    im_as_ten.unsqueeze_(0)
    im_as_var = Variable(im_as_ten, requires_grad=True)
    
    return im_as_var

# %%
def recreate_image(im_as_var):
    reverse_mean = [-0.4914, -0.4822, -0.4465]
    reverse_std = [1/0.2023, 1/0.1994, 1/0.2010]
    recreated_im = copy.copy(im_as_var.cpu().data.numpy()[0])
    for c in range(3):
        recreated_im[c] /= reverse_std[c]
        recreated_im[c] -= reverse_mean[c]
    recreated_im[recreated_im > 1] = 1
    recreated_im[recreated_im < 0] = 0
    recreated_im = np.round(recreated_im * 255)

    recreated_im = np.uint8(recreated_im).transpose(1, 2, 0)
    
    return recreated_im

# %%
def save_image(im, path):
    if isinstance(im, (np.ndarray, np.generic)):
        if np.max(im) <= 1:
            im = (im*255).astype(np.uint8)
        im = Image.fromarray(im)
    im.save(path)

# %%
target_class = 5
created_image = np.uint8(np.random.uniform(0, 255, (224, 224, 3)))

if not os.path.exists('./generated'):
    os.makedirs('./generated')

initial_learning_rate = 20
for i in range(1, 150):
    processed_image = preprocess_image(created_image)
    optimizer = SGD([processed_image], lr=initial_learning_rate)
    output = model(processed_image.to(device))
    class_loss = -output[0, target_class]
    print('Iteration:', str(i), 'Loss', "{0:.2f}".format(class_loss.cpu().data.numpy()))
    
    model.zero_grad()
    
    class_loss.backward()
    # Update image
    optimizer.step()
    # Recreate image
    created_image = recreate_image(processed_image)
    if i % 10 == 0:
        # Save image
        im_path = './generated/c_specific_iteration_'+str(i)+'.jpg'
        save_image(created_image, im_path)
# Out:
# Iteration: 1 Loss -3.77
# Iteration: 2 Loss -12.21
# Iteration: 3 Loss -19.46
# Iteration: 4 Loss -23.34
# Iteration: 5 Loss -28.65
# Iteration: 6 Loss -32.47
# Iteration: 7 Loss -33.94
# Iteration: 8 Loss -40.98
# Iteration: 9 Loss -45.15
# Iteration: 10 Loss -43.58
# Iteration: 11 Loss -48.33
# Iteration: 12 Loss -59.08
# Iteration: 13 Loss -62.08
# Iteration: 14 Loss -62.64
# Iteration: 15 Loss -60.13
# Iteration: 16 Loss -66.45
# Iteration: 17 Loss -69.14
# Iteration: 18 Loss -69.24
# Iteration: 19 Loss -74.45
# Iteration: 20 Loss -76.38
# Iteration: 21 Loss -82.37
# Iteration: 22 Loss -83.03
# Iteration: 23 Loss -83.87
# Iteration: 24 Loss -79.00
# Iteration: 25 Loss -87.11
# Iteration: 26 Loss -88.74
# Iteration: 27 Loss -88.49
# Iteration: 28 Loss -86.40
# Iteration: 29 Loss -93.64
# Iteration: 30 Loss -100.64
# Iteration: 31 Loss -101.16
# Iteration: 32 Loss -104.57
# Iteration: 33 Loss -104.14
# Iteration: 34 Loss -100.81
# Iteration: 35 Loss -106.27
# Iteration: 36 Loss -114.26
# Iteration: 37 Loss -108.75
# Iteration: 38 Loss -115.66
# Iteration: 39 Loss -120.86
# Iteration: 40 Loss -122.41
# Iteration: 41 Loss -121.12
# Iteration: 42 Loss -126.27
# Iteration: 43 Loss -118.05
# Iteration: 44 Loss -122.51
# Iteration: 45 Loss -121.22
# Iteration: 46 Loss -119.21
# Iteration: 47 Loss -115.94
# Iteration: 48 Loss -118.11
# Iteration: 49 Loss -127.13
# Iteration: 50 Loss -129.19
# Iteration: 51 Loss -126.92
# Iteration: 52 Loss -129.08
# Iteration: 53 Loss -129.65
# Iteration: 54 Loss -137.82
# Iteration: 55 Loss -140.20
# Iteration: 56 Loss -139.97
# Iteration: 57 Loss -137.19
# Iteration: 58 Loss -141.56
# Iteration: 59 Loss -139.02
# Iteration: 60 Loss -140.75
# Iteration: 61 Loss -135.13
# Iteration: 62 Loss -141.86
# Iteration: 63 Loss -141.04
# Iteration: 64 Loss -145.59
# Iteration: 65 Loss -143.55
# Iteration: 66 Loss -146.25
# Iteration: 67 Loss -149.86
# Iteration: 68 Loss -149.14
# Iteration: 69 Loss -150.64
# Iteration: 70 Loss -152.39
# Iteration: 71 Loss -153.08
# Iteration: 72 Loss -148.16
# Iteration: 73 Loss -150.11
# Iteration: 74 Loss -154.20
# Iteration: 75 Loss -155.73
# Iteration: 76 Loss -156.95
# Iteration: 77 Loss -154.63
# Iteration: 78 Loss -154.50
# Iteration: 79 Loss -160.44
# Iteration: 80 Loss -161.55
# Iteration: 81 Loss -159.98
# Iteration: 82 Loss -159.61
# Iteration: 83 Loss -160.29
# Iteration: 84 Loss -163.64
# Iteration: 85 Loss -165.89
# Iteration: 86 Loss -162.17
# Iteration: 87 Loss -164.92
# Iteration: 88 Loss -162.97
# Iteration: 89 Loss -155.90
# Iteration: 90 Loss -169.40
# Iteration: 91 Loss -166.66
# Iteration: 92 Loss -174.62
# Iteration: 93 Loss -172.19
# Iteration: 94 Loss -178.64
# Iteration: 95 Loss -171.56
# Iteration: 96 Loss -173.55
# Iteration: 97 Loss -168.79
# Iteration: 98 Loss -174.49
# Iteration: 99 Loss -177.33
# Iteration: 100 Loss -178.80
# Iteration: 101 Loss -178.41
# Iteration: 102 Loss -173.57
# Iteration: 103 Loss -177.62
# Iteration: 104 Loss -174.14
# Iteration: 105 Loss -175.30
# Iteration: 106 Loss -173.66
# Iteration: 107 Loss -173.27
# Iteration: 108 Loss -172.21
# Iteration: 109 Loss -174.38
# Iteration: 110 Loss -170.10
# Iteration: 111 Loss -174.27
# Iteration: 112 Loss -174.61
# Iteration: 113 Loss -174.49
# Iteration: 114 Loss -173.26
# Iteration: 115 Loss -179.47
# Iteration: 116 Loss -179.98
# Iteration: 117 Loss -184.01
# Iteration: 118 Loss -185.93
# Iteration: 119 Loss -188.68
# Iteration: 120 Loss -186.76
# Iteration: 121 Loss -180.85
# Iteration: 122 Loss -186.08
# Iteration: 123 Loss -182.65
# Iteration: 124 Loss -187.56
# Iteration: 125 Loss -188.32
# Iteration: 126 Loss -191.62
# Iteration: 127 Loss -189.55
# Iteration: 128 Loss -186.00
# Iteration: 129 Loss -183.58
# Iteration: 130 Loss -188.31
# Iteration: 131 Loss -196.95
# Iteration: 132 Loss -197.49
# Iteration: 133 Loss -194.42
# Iteration: 134 Loss -192.90
# Iteration: 135 Loss -187.17
# Iteration: 136 Loss -192.35
# Iteration: 137 Loss -195.79
# Iteration: 138 Loss -195.04
# Iteration: 139 Loss -196.95
# Iteration: 140 Loss -198.64
# Iteration: 141 Loss -197.08
# Iteration: 142 Loss -196.12
# Iteration: 143 Loss -192.11
# Iteration: 144 Loss -191.16
# Iteration: 145 Loss -193.22
# Iteration: 146 Loss -193.44
# Iteration: 147 Loss -200.82
# Iteration: 148 Loss -202.78
# Iteration: 149 Loss -203.59
